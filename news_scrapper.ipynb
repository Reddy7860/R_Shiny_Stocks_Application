# %%
# Import libraries
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# NLTK VADER for sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
import urllib, json
import urllib.request as ur

# %%
url = "https://economictimes.indiatimes.com/markets/stocks/news/metal-fmcg-stocks-lift-sensex-as-dalal-street-breaks-two-day-losing-streak/articleshow/81705687.cms"

# %%
from lxml import html
import requests

# page = requests.get('https://economictimes.indiatimes.com/markets/stocks/news/metal-fmcg-stocks-lift-sensex-as-dalal-street-breaks-two-day-losing-streak/articleshow/81705687.cms')
page = requests.get('https://economictimes.indiatimes.com/industry/energy/power/all-india-energy-demand-to-be-higher-in-january-march-india-ratings-and-research/articleshow/81711785.cms')
tree = html.fromstring(page.content)
# #This will create a list of buyers:

buyers = tree.xpath('.//div[@class="artText"]/text()')
# #This will create a list of prices
# prices = tree.xpath('//span[@class="item-price"]/text()')

buyers
# Out:
# ['The all-India ',
#  ' is expected to be higher in March quarter of 2020-21 compared to same period a year ago despite the partial lockdown in some states due to a surge in COVID-19 cases, India Ratings and Research (Ind-Ra) said.\n',
#  '\n',
#  'Ind-Ra has published the March 2021 edition of its credit news digest on the power sector.\n',
#  '\n',
#  'The report highlights the trends in the power sector, with a focus on capacity addition, generation, transmission, merchant power, deficit, regulatory changes and the recent rating actions by Ind-Ra.\n',
#  '\n',
#  '"The all-India energy demand is expected to be higher in 4QFY21 on a year-on-year basis, despite partial lockdowns in some of the states on account of an increase in COVID 19 cases," it said.\n',
#  '\n',
#  'In February 2021, the all-India energy demand increased 0.2 per cent year-on-year to 104.6 billion units.\n',
#  '\n',
#  'The energy demand in April-February 2020-21 was lower by 2.8 per cent, the report said.\n',
# ...

# %%
import spacy
import unicodedata
import re
from nltk.corpus import stopwords
ADDITIONAL_STOPWORDS = ['covfefe']

# %%
# !pip3 install -U spacy
# !python3 -m spacy download en_core_web_sm
# Out:
# ...
# /usr/local/bin/python3: No module named spacy

# %%
for line in buyers:
    wnl = nltk.stem.WordNetLemmatizer()
    stopwords = nltk.corpus.stopwords.words('english')
    text = (unicodedata.normalize('NFKD', line)
        .encode('ascii', 'ignore')
        .decode('utf-8', 'ignore')
        .lower())
    words = re.sub(r'[^\w\s]', '', text).split()
    
    filtered_tokens = [wnl.lemmatize(word) for word in words if word not in stopwords]
#     filtered_tokens = [token for token in str(line).split() if not token.is_stop]

#     all_words = nltk.FreqDist(w.lower() for w in str(line).split())
#     print(filtered_tokens)
    
#     res = [sub.split() for sub in filtered_tokens]
    
#     temp = [token for token in res if not token.is_stop]
    
#     print(temp)

#     print(b.correct())
#     print(str(line))
#     print(.words())
#     newlist = [str(s) for s in line]
#     print(newlist)
#     print(line.words())
#     words=[]
#     all_words = nltk.FreqDist(w.lower() for w in line.words())

# %%
def basic_clean(text):
#     print(text)
    wnl = nltk.stem.WordNetLemmatizer()
    filtered_tokens = []
    stopwords = nltk.corpus.stopwords.words('english')
    
    text = (unicodedata.normalize('NFKD', text)
        .encode('ascii', 'ignore')
        .decode('utf-8', 'ignore')
        .lower())
    words = re.sub(r'[^\w\s]', '', text).split()

    filtered_tokens = [wnl.lemmatize(word) for word in words if word not in stopwords]
    return filtered_tokens

# %%
import numpy as np
temp = pd.DataFrame(buyers)

words = basic_clean(''.join(str(temp[0].tolist())))
words
# temp[0].apply(lambda row: temp[0].tolist())
# temp.drop(temp.iloc[,0].str.contains('\n').index)
# Out:
# ['allindia',
#  'expected',
#  'higher',
#  'march',
#  'quarter',
#  '202021',
#  'compared',
#  'period',
#  'year',
#  'ago',
#  'despite',
#  'partial',
#  'lockdown',
#  'state',
#  'due',
#  'surge',
#  'covid19',
#  'case',
#  'india',
#  'rating',
#  'research',
#  'indra',
#  'saidn',
#  'n',
#  'indra',
#  'published',
#  'march',
#  '2021',
#  'edition',
#  'credit',
#  'news',
#  'digest',
#  'power',
#  'sectorn',
#  'n',
#  'report',
#  'highlight',
#  'trend',
#  'power',
#  'sector',
#  'focus',
#  'capacity',
#  'addition',
#  'generation',
#  'transmission',
#  'merchant',
#  'power',
#  'deficit',
#  'regulatory',
#  'change',
#  'recent',
#  'rating',
#  'action',
#  'indran',
#  'n',
#  'allindia',
#  'energy',
#  'demand',
#  'expected',
#  'higher',
#  '4qfy21',
#  'yearonyear',
#  'basis',
#  'despite',
#  'partial',
#  'lockdown',
#  'state',
#  'account',
#  'increase',
#  'covid',
#  '19',
#  'case',
#  'saidn',
#  'n',
#  'february',
#  '2021',
# ...

# %%
from textblob import TextBlob
temp['polarity'] = temp[0].apply(lambda x: TextBlob(x).polarity)
temp['subjective'] = temp[0].apply(lambda x: TextBlob(x).subjectivity)

# %%
temp = temp.rename(columns = {0: 'News', 'polarity': 'polarity','subjective':'subjective'}, inplace = False)

# %%
# Instantiate the sentiment intensity analyzer
vader = SentimentIntensityAnalyzer()

# Iterate through the headlines and get the polarity scores using vader
scores = temp['News'].apply(vader.polarity_scores).tolist()


# Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)


# # Join the DataFrames of the news and the list of dicts
temp = temp.join(scores_df, rsuffix='_right')

# %%
result_df = temp[temp['News'] != '\n']

# %%
result_df = result_df.reset_index(inplace = False)

# %%
result_df = result_df.drop(['index'], axis = 1)

# %%
result_df
# Out:
#                                                  News  polarity  subjective  \
# 0                                      The all-India   0.000000    0.000000
# 1    is expected to be higher in March quarter of ... -0.015000    0.340000
# 2   Ind-Ra has published the March 2021 edition of...  0.000000    0.000000
# 3   The report highlights the trends in the power ...  0.000000    0.250000
# 4   "The all-India energy demand is expected to be...  0.016667    0.400000
# 5   In February 2021, the all-India energy demand ...  0.000000    0.000000
# 6   The energy demand in April-February 2020-21 wa...  0.000000    0.000000
# 7                      The short-term power price at   0.000000    0.000000
# 8    continued its improving trend on a year-on-ye...  0.250000    0.333333
# 9   In February 2021, a 19.5 per cent increase (5,...  0.000000    0.000000
# 10  The electricity generation increased by 0.1 pe...  0.000000    0.000000
# ...

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/apple/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Import libraries
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# NLTK VADER for sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer

finwiz_url = 'https://finviz.com/quote.ashx?t='

# %%
news_tables = {}
tickers = ['AMZN', 'TSLA', 'GOOG']

for ticker in tickers:
    url = finwiz_url + ticker
    req = Request(url=url,headers={'user-agent': 'my-app/0.0.1'}) 
    response = urlopen(req)    
    # Read the contents of the file into 'html'
    html = BeautifulSoup(response)
    # Find 'news-table' in the Soup and load it into 'news_table'
    news_table = html.find(id='news-table')
    # Add the table to our dictionary
    news_tables[ticker] = news_table

# %%
# Read one single day of headlines for 'AMZN' 
amzn = news_tables['AMZN']
# Get all the table rows tagged in HTML with <tr> into 'amzn_tr'
amzn_tr = amzn.findAll('tr')

for i, table_row in enumerate(amzn_tr):
    # Read the text of the element 'a' into 'link_text'
    a_text = table_row.a.text
    # Read the text of the element 'td' into 'data_text'
    td_text = table_row.td.text
    # Print the contents of 'link_text' and 'data_text' 
    print(a_text)
    print(td_text)
    # Exit after printing 4 rows of data
    if i == 3:
        break
# Out:
# Four Tech Stocks That Could Be Winners
# Mar-26-21 08:00PM
# Amazon's social media team bares its teeth in Washington
# 06:35PM
# Amazon's social media team bares its teeth in Washington
# 06:04PM
# Amazon's social media team bares its teeth in Washington
# 05:53PM

# %%
parsed_news = []

# Iterate through the news
for file_name, news_table in news_tables.items():
    # Iterate through all tr tags in 'news_table'
    for x in news_table.findAll('tr'):
        # read the text from each tr tag into text
        # get text from a only
        text = x.a.get_text() 
        # splite text in the td tag into a list 
        date_scrape = x.td.text.split()
        # if the length of 'date_scrape' is 1, load 'time' as the only element

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        # else load 'date' as the 1st element and 'time' as the second    
        else:
            date = date_scrape[0]
            time = date_scrape[1]
        # Extract the ticker from the file name, get the string up to the 1st '_'  
        ticker = file_name.split('_')[0]
        
        # Append ticker, date, time and headline as a list to the 'parsed_news' list
        parsed_news.append([ticker, date, time, text])
        
parsed_news
# Out:
# [['AMZN', 'Mar-26-21', '08:00PM', 'Four Tech Stocks That Could Be Winners'],
#  ['AMZN',
#   'Mar-26-21',
#   '06:35PM',
#   "Amazon's social media team bares its teeth in Washington"],
#  ['AMZN',
#   'Mar-26-21',
#   '06:04PM',
#   "Amazon's social media team bares its teeth in Washington"],
#  ['AMZN',
#   'Mar-26-21',
#   '05:53PM',
#   "Amazon's social media team bares its teeth in Washington"],
#  ['AMZN',
#   'Mar-26-21',
#   '02:37PM',
#   'Tech stocks are going to do vey well going forward: Expert'],
#  ['AMZN',
#   'Mar-26-21',
#   '01:17PM',
#   'Amazon mocked idea its drivers urinated in bottles  but leaked documents show they did'],
#  ['AMZN',
#   'Mar-26-21',
#   '01:12PM',
#   'New lawsuit accuses Amazon of fixing book prices'],
#  ['AMZN',
#   'Mar-26-21',
#   '01:11PM',
#   'ThredUp CEO on IPO day: Dont tax resale and Amazons speed is a fading trend for young shoppers'],
#  ['AMZN',
#   'Mar-26-21',
#   '12:54PM',
# ...

# %%
# Instantiate the sentiment intensity analyzer
vader = SentimentIntensityAnalyzer()

# Set column names
columns = ['ticker', 'date', 'time', 'headline']

# Convert the parsed_news list into a DataFrame called 'parsed_and_scored_news'
parsed_and_scored_news = pd.DataFrame(parsed_news, columns=columns)


# Iterate through the headlines and get the polarity scores using vader
scores = parsed_and_scored_news['headline'].apply(vader.polarity_scores).tolist()


# Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)


# # Join the DataFrames of the news and the list of dicts
parsed_and_scored_news = parsed_and_scored_news.join(scores_df, rsuffix='_right')

# Convert the date column from string to datetime
parsed_and_scored_news['date'] = pd.to_datetime(parsed_and_scored_news.date).dt.date

parsed_and_scored_news.head()
# Out:
#        neg    neu    pos  compound
# 0    0.000  0.659  0.341    0.4767
# 1    0.000  1.000  0.000    0.0000
# 2    0.000  1.000  0.000    0.0000
# 3    0.000  1.000  0.000    0.0000
# 4    0.000  0.826  0.174    0.2732
# ..     ...    ...    ...       ...
# 295  0.000  1.000  0.000    0.0000
# 296  0.000  1.000  0.000    0.0000
# 297  0.000  1.000  0.000    0.0000
# 298  0.000  1.000  0.000    0.0000
# 299  0.194  0.620  0.186   -0.0258
#
# [300 rows x 4 columns]

# %%
import http.client
conn = http.client.HTTPSConnection("apiconnect.angelbroking.com")
payload = "{\r\n     \"exchange\": \"NSE\",\r\n  \"symboltoken\": \"3045\",\r\n     \"interval\": \"ONE_MINUTE\",\r\n  \"fromdate\": \"2021-02-08 09:00\",\r\n     \"todate\": \"2021-02-08 09:16\"\r\n}"

# %%
headers = {
  'X-PrivateKey': 'LPUVlRxd',
  'Accept': 'application/json',
  'X-SourceID': 'WEB',
  'X-ClientLocalIP': '192.168.168.168',
  'X-ClientPublicIP': '106.193.147.98',
  'X-MACAddress': 'fe80::216e:6507:4b90:3719',
  'X-UserType': 'USER',
  'Authorization': 'Bearer eyJhbGciOiJIUzUxMiJ9.eyJ1c2VybmFtZSI6IkQ4ODMiLCJyb2xlcyI6MCwidXNlcnR5cGUiOiJVU0VSIiwiaWF0IjoxNTk5NzEyNjk4LCJleHAiOjE1OTk3MjE2OTh9.qHZEkOMokMktybarQO3m4NMRVQlF0vvN7rh2lCRkjd2sCYBq3JnOq0yWWOS5Ux_H0pvvt4-ibSmb5HJoKJHOUw',
  'Accept': 'application/json',
  'X-SourceID': 'WEB',
  'Content-Type': 'application/json'
}

# %%
conn.request("POST", "/rest/secure/angelbroking/historical/v1/getCandleData", payload, headers)
res = conn.getresponse()
data = res.read()
print(data.decode("utf-8"))
# Out:
# {"success":false,"message":"Invalid Token","errorCode":"AG8001","data":""}

# %%
import http.client
import mimetypes
conn = http.client.HTTPSConnection(
    "apiconnect.angelbroking.com"
    )
payload = "{'clientcode':'J95213','password':'startteja123'}"
headers = {
    'Content-Type': 'application/json',
    'Accept': 'application/json',
    'X-UserType': 'USER',
    'X-SourceID': 'WEB',
    'X-ClientLocalIP': '192.168.168.168',
    'X-ClientPublicIP': '106.193.147.98',
    'X-MACAddress': 'fe80::216e:6507:4b90:3719',
    'X-PrivateKey': 'LPUVlRxd'
  }
conn.request(
    "POST", 
    "/rest/auth/angelbroking/user/v1/loginByPassword",
     payload,
     headers)

res = conn.getresponse()
data = res.read()
print(data.decode("utf-8"))

# %%
data.decode("utf-8")
# Out:
# ''

# %%
import http.client
import mimetypes
conn = http.client.HTTPSConnection(
    "apiconnect.angelbroking.com"
    )
payload = ''
headers = headers = {
    'Authorization': 'Bearer eyJhbGciOiJIUzUxMiJ9.eyJ1c2VybmFtZSI6Iko5NTIxMyIsInJvbGVzIjowLCJ1c2VydHlwZSI6IlVTRVIiLCJpYXQiOjE2MTgyMjI5ODEsImV4cCI6MTcwNDYyMjk4MX0.qkiH5PRubZAm7E38lvWc3bUZwmWTym6fHj-m1hK8E6Pdfuw-9-rsBBdx7WzKffQytjqJM_regiLwfcTmd_Ao8Q',
    'Accept': 'application/json',
    'X-UserType': 'USER',
    'X-SourceID': 'WEB',
    'X-ClientLocalIP': '192.168.168.168',
    'X-ClientPublicIP': '106.193.147.98',
    'X-MACAddress': 'fe80::216e:6507:4b90:3719',
    'X-PrivateKey': 'LPUVlRxd'
  }
conn.request("GET",
 "/rest/secure/angelbroking/user/v1/getProfile", 
 payload,
 headers)
res = conn.getresponse()
data = res.read()
print(data.decode("utf-8"))
# Out:
# {"status":true,"message":"SUCCESS","errorcode":"","data":{"clientcode":"J95213","name":"JONNALA TEJA REDDY","email":"","mobileno":"","exchanges":["bse_cm","nse_cm","cde_fo","mcx_fo","ncx_fo","nse_fo"],"products":["BO","NRML","CO","CNC","MIS","MARGIN"],"lastlogintime":"","broker":""}}

# %%
import http.client
import mimetypes
conn = http.client.HTTPSConnection(
    "apiconnect.angelbroking.com"
    )
payload = ''
headers = {
    'Authorization': 'Bearer eyJhbGciOiJIUzUxMiJ9.eyJ1c2VybmFtZSI6Iko5NTIxMyIsInJvbGVzIjowLCJ1c2VydHlwZSI6IlVTRVIiLCJpYXQiOjE2MTgyMjI5ODEsImV4cCI6MTcwNDYyMjk4MX0.qkiH5PRubZAm7E38lvWc3bUZwmWTym6fHj-m1hK8E6Pdfuw-9-rsBBdx7WzKffQytjqJM_regiLwfcTmd_Ao8Q',
    'Content-Type': 'application/json',
    'Accept': 'application/json',
    'X-UserType': 'USER',
    'X-SourceID': 'WEB',
    'X-ClientLocalIP': '192.168.168.168',
    'X-ClientPublicIP': '106.193.147.98',
    'X-MACAddress': 'fe80::216e:6507:4b90:3719',
    'X-PrivateKey': 'LPUVlRxd'
  }
conn.request("GET", 
"/rest/secure/angelbroking/user/v1/getRMS", 
payload, 
headers)

res = conn.getresponse()
data = res.read()
print(data.decode("utf-8"))
# Out:
# {"status":true,"message":"SUCCESS","errorcode":"","data":{"net":"4868.680000000000291","availablecash":"4868.680000000000291","availableintradaypayin":"20000","availablelimitmargin":"0","collateral":"0","m2munrealized":"0","m2mrealized":"650","utiliseddebits":"29050","utilisedspan":"0","utilisedoptionpremium":"0","utilisedholdingsales":"0","utilisedexposure":"0","utilisedturnover":"0","utilisedpayout":"0"}}

# %%
import http.client
import mimetypes
conn = http.client.HTTPSConnection(
    "apiconnect.angelbroking.com"
    )
payload = "{'clientcode':'J95213'}"
headers = {
    'Authorization': 'Bearer eyJhbGciOiJIUzUxMiJ9.eyJ1c2VybmFtZSI6Iko5NTIxMyIsInJvbGVzIjowLCJ1c2VydHlwZSI6IlVTRVIiLCJpYXQiOjE2MTgyMjI5ODEsImV4cCI6MTcwNDYyMjk4MX0.qkiH5PRubZAm7E38lvWc3bUZwmWTym6fHj-m1hK8E6Pdfuw-9-rsBBdx7WzKffQytjqJM_regiLwfcTmd_Ao8Q',
    'Content-Type': 'application/json',
    'Accept': 'application/json',
    'X-UserType': 'USER',
    'X-SourceID': 'WEB',
    'X-ClientLocalIP': '192.168.168.168',
    'X-ClientPublicIP': '106.193.147.98',
    'X-MACAddress': 'fe80::216e:6507:4b90:3719',
    'X-PrivateKey': 'LPUVlRxd'
  }
conn.request("POST",
"/rest/secure/angelbroking/user/v1/logout", 
payload, 
headers)
res = conn.getresponse()
data = res.read()
print(data.decode("utf-8"))

# %%
import http.client

conn = http.client.HTTPSConnection("apiconnect.angelbroking.com")
historicParam="{'exchange': 'NSE','symboltoken': '547','interval': 'FIFTEEN_MINUTE','fromdate': '2021-04-07 09:00','todate': '2021-04-07 09:15'}"

# payload = "{'exchange': 'NSE','symboltoken': '3045','interval': 'ONE_MINUTE','fromdate': '2021-04-08 09:00','todate': '2021-04-08 09:16'}"
headers = {
  'X-PrivateKey': 'LPUVlRxd',
  'Accept': 'application/json',
  'X-SourceID': 'WEB',
  'X-ClientLocalIP': '192.168.168.168',
  'X-ClientPublicIP': '106.193.147.98',
  'X-MACAddress': 'fe80::216e:6507:4b90:3719',
  'X-UserType': 'USER',
  'Authorization': 'Bearer eyJhbGciOiJIUzUxMiJ9.eyJ1c2VybmFtZSI6Iko5NTIxMyIsInJvbGVzIjowLCJ1c2VydHlwZSI6IlVTRVIiLCJpYXQiOjE2MTgyMjI5ODEsImV4cCI6MTcwNDYyMjk4MX0.qkiH5PRubZAm7E38lvWc3bUZwmWTym6fHj-m1hK8E6Pdfuw-9-rsBBdx7WzKffQytjqJM_regiLwfcTmd_Ao8Q',
  'Accept': 'application/json',
  'X-SourceID': 'WEB',
  'Content-Type': 'application/json'
}
conn.request("POST", "/rest/secure/angelbroking/historical/v1/getCandleData", historicParam, headers)
res = conn.getresponse()
data = res.read()
print(data.decode("utf-8"))

# %%
res.read()
# Out:
# b''

# %%
import requests
import pandas as pd

# %%
resp = requests.get(url = "https://query1.finance.yahoo.com/v8/finance/chart/RELIANCE.NS?region=IN&lang=en-IN&includePrePost=false&interval=1m&range=2d&corsDomain=in.finance.yahoo.com&.tsrc=financet")

# %%
json_resp = resp.json()

# %%
stock_timestamp = json_resp['chart']['result'][0]['timestamp']
Close = json_resp['chart']['result'][0]['indicators']['quote'][0]['close']
High = json_resp['chart']['result'][0]['indicators']['quote'][0]['high']
Low = json_resp['chart']['result'][0]['indicators']['quote'][0]['low']
Open = json_resp['chart']['result'][0]['indicators']['quote'][0]['open']
Volume = json_resp['chart']['result'][0]['indicators']['quote'][0]['volume']

# %%
data = {'timestamp':stock_timestamp,
        'open':Open,
        'high':High,
        'low':Low,
        'close':Close,
        'volume':Volume}

# %%
final_df = pd.DataFrame(data)

# %%
import datetime
final_df['timestamp']=final_df['timestamp'].apply(lambda d: datetime.datetime.fromtimestamp(int(d)).strftime('%Y-%m-%d %H:%M:%S'))

# %%
final_df
# Out:
#                timestamp         open         high          low        close  \
# 0    2021-04-09 09:15:00  1997.699951  1999.900024  1985.699951  1988.699951
# 1    2021-04-09 09:16:00  1988.900024  1993.400024  1986.699951  1990.599976
# 2    2021-04-09 09:17:00  1992.050049  1997.000000  1991.199951  1993.500000
# 3    2021-04-09 09:18:00  1993.400024  1996.000000  1991.449951  1992.300049
# 4    2021-04-09 09:19:00  1992.000000  1995.250000  1991.400024  1994.000000
# ..                   ...          ...          ...          ...          ...
# 745  2021-04-12 15:25:00  1917.849976  1918.150024  1917.449951  1917.500000
# 746  2021-04-12 15:26:00  1917.550049  1917.650024  1917.500000  1917.550049
# 747  2021-04-12 15:27:00  1917.500000  1919.150024  1917.000000  1919.000000
# 748  2021-04-12 15:28:00  1919.050049  1919.949951  1915.000000  1915.099976
# 749  2021-04-12 15:29:00  1915.099976  1917.349976  1913.199951  1917.000000
#
#       volume
# 0        0.0
# 1    82494.0
# ...

# %%
from datetime import datetime
print(type(stock_timestamp))
# stock_timestamp = int(stock_timestamp)
# print(datetime.utcfromtimestamp(stock_timestamp).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# <class 'list'>

# %%
pip install smartapi
# Out:
# Processing /Users/apple/Library/Caches/pip/wheels/dc/1f/93/9875b2bba4b85ce5317774b2fa5eff6a953e8e7f76b228d0bc/SmartAPI-1.1.0-py3-none-any.whl
# Processing /Users/apple/Library/Caches/pip/wheels/3a/97/90/e133cbb98e344c2ca55120f8d704f6ff57bdfd8e30f1dc5451/rdflib_jsonld-0.5.0-py2.py3-none-any.whl
# ...
#   Using cached pycrypto-2.6.1.tar.gz (446 kB)
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /Users/apple/opt/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/5h/522frwxx13zg6wtt8w511_pw0000gn/T/pip-install-oydi19bi/pycrypto/setup.py'"'"'; __file__='"'"'/private/var/folders/5h/522frwxx13zg6wtt8w511_pw0000gn/T/pip-install-oydi19bi/pycrypto/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/5h/522frwxx13zg6wtt8w511_pw0000gn/T/pip-wheel-ti783yhc
# ...
